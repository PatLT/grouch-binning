# %%
import numpy as np
import pandas as pd
from os import listdir
import matplotlib.pyplot as plt
from importlib import reload
import tqdm.notebook as tqdm

# %%
from os import sys
sys.path.append("..")
from grouch import binning
from grouch import plotting

# %% [markdown]
# # Binning analysis
# The basic idea of the binning code is to visualise the distribution of different measured _variables_ (metrics) e.g. photodiode intensity, spatter, etc. by binning them against different _coordinates_ (independent variables) e.g. spatial position, scan orientation, etc.
# The resulting bins can be visualised in different ways by plotting different quantities per bin such as the mean, count, or standard deviation for a given variable.
# The easiest way to get what this is about is to look at [the notebook](binning_v2.ipynb).
#
# ### _Code breakdown_
# The key parts of the code are:
# * The `DataBins` object, which stores all the data for a particular coordinate or set of coordinates in bins.
# * The `process_dataframe` function, which takes a pandas dataframe and any number of `DataBins` instances as input, then carries out the appropriate binning over the dataframe.
#
# The rest of the code in [fast_binning.py](fast_binning.py) basically consists of various helper functions.
# * `optimal_grid` can be used to generate appropriate bins given an initial user 'guess'. This is helpful for binning against 'sparse' coordinates, such as XY plane coordinates (for certain builds).
# * `expand_df` adds some common 'derived' variables and coordinates into an initial dataframe: orientation, speed, acceleration, distance traversed.
# * `plot_bins` produces a quick plot from 3 `DataBins` with coordinates corresponding to build height, XY position, and scan path orientation.
#
# ### Demonstration

# %%
dir_ = "onderive_data_2/12Hz/"

# %%
# grab a random file and use it to work out what metrics need to be included in the binning procedure.
test_path = dir_ + "layer360.csv"
test = pd.read_csv(test_path,header=0,index_col=0)
var_labels = test.loc[:,"Photodiode":].columns.drop(["Z","Frame","Layer"]) # a list of metrics that correspond to dependent variables. 
var_labels = var_labels.append(pd.Index(["Distance traversed"])) # An extra variable, it's value is calculated by the expand_df function.

# Also use the test file to work out a rough bin 'mesh' for the build bed plane bins. 
x_grid,y_grid = binning.optimal_grid(["X","Y"],
                                          test,
                                          [4,4],
                                          sub_divisions=6,
                                          aux_variable="P",
                                          tol=1000.0)

# %%
example = binning.expand_df(test)
xmin = -76000 ; xmax = -72000
ymin = 74000 ; ymax = 78000

example = example[(example.loc[:,"P"]>0.0)
                  & (example.loc[:,"X"]<-xmax) & (example.loc[:,"X"]>xmin) 
                  & (example.loc[:,"Y"]<ymax) & (example.loc[:,"Y"]>ymin)]

fig,ax = plt.subplots(ncols=2,figsize=(12,6))

ax[0].scatter(example.loc[:,"X"].values,example.loc[:,"Y"].values,
           #c=(example.loc[:,"X"].values-xmin)+(example.loc[:,"Y"].values-ymin)*(xmax-xmin),
           s=0.5,
           cmap="spring")
ax[0].set_aspect("equal")
ax[0].set_xlim([xmin,xmax])
ax[0].set_ylim([ymin,ymax])

ax[0].annotate("Variables:\n"+example.iloc[300].loc["Photodiode":"Spot area (um2)"].to_string(),
               example.iloc[300].loc["X":"Y"].to_numpy(),
               example.iloc[300].loc["X":"Y"].to_numpy()+np.array([-1000,1000]),
               arrowprops={"width":0.3})

ax[1].scatter(example.loc[:,"X"].values,example.loc[:,"Y"].values,
           c=example.loc[:,"Orientation"].values,
           s=0.5,
           cmap="spring")
ax[1].set_aspect("equal")
ax[1].set_xlim([xmin,xmax])
ax[1].set_ylim([ymin,ymax])

ax[1].text(-75000,77000,"Coloured by coordinate:\norientation")
# Out:
# /tmp/ipykernel_1890/101865346.py:11: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   ax[0].scatter(example.loc[:,"X"].values,example.loc[:,"Y"].values,
# Text(-75000, 77000, 'Coloured by coordinate:\norientation')

# %% [markdown]
# ## 12Hz blower frequency data
# Data processing pipeline:
# - Setup appropriate bins (semi-automated)
# - expand with additional variables
# - compute binning
#
# The variable `dir_` should point to the directory containing all of the ATLAS metrics csv files for a build.

# %%
# Setup objects that correspond to the bins over 'coordinates'. 
XY_data = binning.DataBins(["X","Y"],[x_grid,y_grid],var_labels)
th_data = binning.DataBins(["Orientation"],[np.linspace(-np.pi,np.pi,41,endpoint=True)],var_labels)
Zl_data = binning.DataBins(["Layer"],[np.arange(0,181,9)-0.5],var_labels)

# %%
# loop over all of the metric csv files, and process using the bin objects. 
for file in tqdm.tqdm(listdir(dir_)):
    df = pd.read_csv(dir_ + file,header=0,index_col=0,engine='c')
    df = binning.expand_df(df) # Calculate extra derived variables. 
    binning.process_dataframe(df,XY_data,th_data,Zl_data)
# If this runs slowly, it's due to the overhead of reading in the csv files (see profiling section at the end of the notebook).
# Should be easy to parallelise if required.
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]

# %% [markdown]
# ## 30Hz blower frequency data
# - repeat the data processing pipeline used above.

# %%
dir_ = "onderive_data_2/30Hz/"

XY_data_30Hz = binning.DataBins(["X","Y"],[x_grid,y_grid],var_labels)
th_data_30Hz = binning.DataBins(["Orientation"],[np.linspace(-np.pi,np.pi,41,endpoint=True)],var_labels)
Zl_data_30Hz = binning.DataBins(["Layer"],[np.arange(0,181,9)-0.5],var_labels)

# %%
for file in tqdm.tqdm(sorted(listdir(dir_),
                             key=lambda f: int(f.split(".")[0][5:]))[:181]
                      ):
    df = pd.read_csv(dir_ + file,header=0,index_col=0,engine='c')
    df = binning.expand_df(df)
    binning.process_dataframe(df,XY_data_30Hz,th_data_30Hz,Zl_data_30Hz)
# Out:
#   0%|          | 0/181 [00:00<?, ?it/s]

# %% [markdown]
# ## Visualisations
# We can visualise these bins for different dependent variables (in this case, different metrics), and different quantities for each bin (e.g. mean values per bin, std per bin, etc.).
#
# First set of bins: mean photodiode values per bin. Plotted against height/layer, XY position in the bed, and scan path orientation.

# %%
fig = plt.figure(figsize=(14.0,7.0))
ax_z,ax_xy,ax_th,vrange_0 = plotting.plot_bins(fig,
                       "Photodiode",
                       XY_data,
                       th_data,
                       Zl_data,
                       "mean",
                       normalisation='linear')
fig.suptitle("12Hz blower build: mean photodiode values")
fig.tight_layout()

# %% [markdown]
# Note that in the second plot, `vrange` returned from the previous plotting function is passed as a variable in order to use the same value range and colorbar as above.

# %%
fig = plt.figure(figsize=(14.0,7.0))
ax_z,ax_xy,ax_th,vrange_0 = plotting.plot_bins(fig,
                       "Photodiode",
                       XY_data_30Hz,
                       th_data_30Hz,
                       Zl_data_30Hz,
                       vrange=vrange_0,
                       quantity="mean",
                       normalisation='linear')
fig.suptitle("30Hz blower build: mean photodiode values")
fig.tight_layout()

# %% [markdown]
# For this second set of bins, the quantity shown is the average total spatter area per unit of distance traversed along the scan path. Note that you can add plot any ATLAS metric here.

# %%
fig = plt.figure(figsize=(14.0,7.0))
ax_z,ax_xy,ax_th,vrange_1 = plotting.plot_bins(fig,
                       "Spatter total area",
                       XY_data,
                       th_data,
                       Zl_data,
                       "per_traversed",
                       normalisation='log')
fig.suptitle("12Hz blower build: averaged total spatter area rate")
fig.tight_layout()

# %%
fig = plt.figure(figsize=(14.0,7.0))
ax_z,ax_xy,ax_th,vrange_1 = plotting.plot_bins(fig,
                       "Spatter total area",
                       XY_data_30Hz,
                       th_data_30Hz,
                       Zl_data_30Hz,
                       vrange=vrange_1,
                       quantity="per_traversed",
                       normalisation='log')
fig.suptitle("30Hz blower build: averaged total spatter area rate")
fig.tight_layout()

# %% [markdown]
# ## Separate binning by component
# Using the 12Hz data again.

# %%
# Once again, use the test file to work out a rough bin 'mesh' for the build bed plane bins. 
dir_ = "onderive_data_2/12Hz/"
test_path = dir_ + "layer360.csv"
test = pd.read_csv(test_path,header=0,index_col=0)
x_grid,y_grid = binning.optimal_grid(["X","Y"],
                                          test,
                                          [4,4],
                                          sub_divisions=1,
                                          aux_variable="P",
                                          tol=1000.0)

# %%
# Setup objects that correspond to the bins over 'coordinates' - here the rough mesh over XY is a proxy for the build components. 
th_component_data = binning.DataBins(["X","Y","Orientation"],
                                          [x_grid,y_grid,np.linspace(-np.pi,np.pi,41,endpoint=True)],
                                          var_labels)

# %%
# Note that due to the large overhead of reading .csv files, it would be faster to do this in the same loop as the one above. 
for file in tqdm.tqdm(listdir(dir_)):
    df = pd.read_csv(dir_ + file,header=0,index_col=0,engine='c')
    df = binning.expand_df(df) # Calculate extra derived variables. 
    binning.process_dataframe(df,th_component_data)
# Out:
#   0%|          | 0/180 [00:00<?, ?it/s]

# %% [markdown]
# DataBins objects can be sliced to produce a new DataBins object. How slices are taken should correspond to the order of the `coord_names` attribute. The code snippet in the cell below gives an example.

# %%
print("original coords = [{},{},{}]".format(*th_component_data.coord_names))
print("original # bins per coord = [{},{},{}]".format(*th_component_data.nbin))
th_component_data_00 = th_component_data[0,0,:]
print("sliced object's coords = [{}]".format(*th_component_data_00.coord_names))
print("sliced object's # bins per coord = [{}]".format(*th_component_data_00.nbin))
# Out:
# original coords = [X,Y,Orientation]
# original # bins per coord = [9,9,42]
# sliced object's coords = [Orientation]
# sliced object's # bins per coord = [42]

# %% [markdown]
# Can make use of slicing to plot orientation bins _per component_ i.e. per XY plane bin.

# %%
fig = plt.figure(figsize=(12,7))
spec = fig.add_gridspec(4,8)

# Just replot the planar data
ax0 = fig.add_subplot(spec[:,:4])
plotting.plot_planar_bins(ax0,XY_data,"Spatter total area","per_traversed",vrange=vrange_1,normalisation='log')

# Now plot bins over orientation for each component.
# Note the strange indexing - component [0,0] is oat the bottom left of the planar plot. 
for i in range(4):
    for j in range(4):
        ax = fig.add_subplot(spec[3-j,4+i],polar=True)
        plotting.plot_orientation_bins(ax,th_component_data[2*i,2*j,:],"Spatter total area","per_traversed",vrange=vrange_1,normalisation='log')
        # Clean up these plots - they're too small for labels really
        ax.set_yticklabels([])
        ax.set_xticklabels([])
        
fig.tight_layout()
fig.suptitle("12Hz blower build: averaged total spatter area rate")
# Out:
# Text(0.5, 0.98, '12Hz blower build: averaged total spatter area rate')

# %% [markdown]
# ## Profiling the code
# The main overhead is from reading in the csv files.

# %%
from copy import deepcopy

# %%
XY_data_test = deepcopy(XY_data_30Hz)
th_data_test = deepcopy(th_data_30Hz)
Zl_data_test = deepcopy(Zl_data_30Hz)

# %%
# %%prun
df = pd.read_csv(dir_ + file,header=0,index_col=0,engine='c')
df = fast_binning.expand_df(df)
fast_binning.process_dataframe(df,XY_data_test,th_data_test,Zl_data_test)
# Out:
#          324666 function calls (319052 primitive calls) in 2.054 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    1.138    1.138    1.149    1.149 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#       350    0.111    0.000    0.111    0.000 {pandas._libs.algos.take_2d_axis0_float64_float64}
#       314    0.073    0.000    0.073    0.000 {built-in method scipy.fft._pocketfft.pypocketfft.c2c}
#  1225/881    0.061    0.000    0.082    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#         2    0.032    0.016    0.057    0.028 managers.py:2224(_merge_blocks)
#       192    0.031    0.000    0.031    0.000 fast_binning.py:10(add_at)
#         4    0.029    0.007    0.029    0.007 managers.py:2194(_stack_arrays)
#      2609    0.026    0.000    0.026    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#        96    0.019    0.000    0.361    0.004 fast_binning.py:245(bin)
#        96    0.016    0.000    0.016    0.000 fast_binning.py:28(addBool_at)
# 61920/61727    0.015    0.000    0.024    0.000 {built-in method builtins.isinstance}
#       639    0.015    0.000    0.015    0.000 {method 'get_loc' of 'pandas._libs.index.IndexEngine' objects}
#       351    0.015    0.000    0.172    0.000 managers.py:691(_slice_take_blocks_ax0)
#       192    0.014    0.000    0.020    0.000 managers.py:1669(_interleave)
#       157    0.013    0.000    0.019    0.000 fast_binning.py:46(adjust_and_pad)
#         1    0.010    0.010    0.028    0.028 fast_binning.py:361(expand_df)
#       129    0.010    0.000    0.010    0.000 {method 'searchsorted' of 'numpy.ndarray' objects}
#       301    0.009    0.000    0.009    0.000 {built-in method _codecs.utf_8_decode}
#         1    0.009    0.009    0.009    0.009 c_parser_wrapper.py:60(__init__)
#       157    0.008    0.000    0.119    0.001 fast_binning.py:93(fft_recon_score)
#       193    0.008    0.000    0.008    0.000 missing.py:261(_isna_array)
#      1435    0.008    0.000    0.134    0.000 take.py:121(_take_nd_ndarray)
#       288    0.007    0.000    0.012    0.000 blocks.py:360(apply)
#       701    0.007    0.000    0.007    0.000 {method 'get_indexer' of 'pandas._libs.index.IndexEngine' objects}
#         1    0.006    0.006    0.753    0.753 fast_binning.py:148(process_dataframe)
#       701    0.006    0.000    0.064    0.000 base.py:3858(get_indexer)
#         1    0.006    0.006    0.006    0.006 {built-in method io.open}
#       703    0.005    0.000    0.414    0.001 indexing.py:1327(_getitem_tuple)
#       927    0.005    0.000    0.007    0.000 generic.py:6147(__finalize__)
#       860    0.005    0.000    0.377    0.000 indexing.py:1359(_getitem_axis)
#         3    0.005    0.002    0.008    0.003 linalg.py:2342(norm)
#       703    0.005    0.000    0.031    0.000 indexing.py:1006(_getitem_lowerdim)
# 17209/12325    0.005    0.000    0.007    0.000 {built-in method builtins.len}
#       446    0.005    0.000    0.366    0.001 indexing.py:978(_getitem_tuple_same_dim)
#       324    0.005    0.000    0.029    0.000 base.py:477(__new__)
#       351    0.004    0.000    0.189    0.001 generic.py:5574(_reindex_with_indexers)
#       703    0.004    0.000    0.433    0.001 indexing.py:1139(__getitem__)
#       350    0.004    0.000    0.108    0.000 base.py:6100(_get_indexer_strict)
#       253    0.004    0.000    0.014    0.000 {method 'get_slice' of 'pandas._libs.internals.BlockManager' objects}
#      4177    0.004    0.000    0.005    0.000 generic.py:562(_get_axis)
#        96    0.004    0.000    0.039    0.000 blocks.py:1256(where)
#       735    0.004    0.000    0.133    0.000 blocks.py:1041(take_nd)
#       288    0.004    0.000    0.060    0.000 blocks.py:1375(fillna)
#       330    0.004    0.000    0.007    0.000 {pandas._libs.lib.maybe_convert_objects}
#      1435    0.004    0.000    0.138    0.000 take.py:59(take_nd)
#       260    0.004    0.000    0.007    0.000 base.py:841(_engine)
#       323    0.003    0.000    0.005    0.000 {pandas._libs.lib.infer_dtype}
#       359    0.003    0.000    0.015    0.000 construction.py:518(sanitize_array)
#       478    0.003    0.000    0.008    0.000 common.py:228(asarray_tuplesafe)
# 3184/2992    0.003    0.000    0.004    0.000 {built-in method numpy.asarray}
#      3262    0.003    0.000    0.007    0.000 {built-in method builtins.any}
#       929    0.003    0.000    0.004    0.000 generic.py:274(__init__)
#        96    0.003    0.000    0.021    0.000 arraylike.py:253(array_ufunc)
#      1969    0.003    0.000    0.003    0.000 {built-in method numpy.empty}
#       927    0.003    0.000    0.005    0.000 base.py:648(_simple_new)
#       350    0.003    0.000    0.007    0.000 base.py:6133(_raise_if_missing)
#      5625    0.003    0.000    0.007    0.000 generic.py:42(_instancecheck)
#      1208    0.003    0.000    0.008    0.000 common.py:1066(is_numeric_dtype)
#      5625    0.003    0.000    0.004    0.000 generic.py:37(_check)
#      8437    0.003    0.000    0.003    0.000 {built-in method builtins.getattr}
#      1752    0.003    0.000    0.005    0.000 indexing.py:1188(_validate_key)
#       192    0.003    0.000    0.077    0.000 managers.py:308(apply)
#       192    0.003    0.000    0.003    0.000 {pandas._libs.algos.take_2d_axis1_float64_float64}
#         1    0.003    0.003    0.003    0.003 {method 'close' of '_io.TextIOWrapper' objects}
#       961    0.003    0.000    0.006    0.000 base.py:5152(_get_engine_target)
#       350    0.003    0.000    0.024    0.000 managers.py:1596(as_array)
#      2676    0.003    0.000    0.003    0.000 {pandas._libs.lib.is_list_like}
#       351    0.003    0.000    0.176    0.001 managers.py:606(reindex_indexer)
#       960    0.003    0.000    0.007    0.000 indexing.py:2678(check_dict_or_set_indexers)
#       196    0.002    0.000    0.002    0.000 {method 'copy' of 'numpy.ndarray' objects}
#       700    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_1d_int64_int64}
#      2051    0.002    0.000    0.002    0.000 {pandas._libs.lib.is_scalar}
#       384    0.002    0.000    0.004    0.000 blocks.py:247(make_block)
#       350    0.002    0.000    0.007    0.000 base.py:1138(take)
#       735    0.002    0.000    0.002    0.000 blocks.py:265(make_block_same_class)
#       703    0.002    0.000    0.004    0.000 indexing.py:1213(_is_scalar_access)
#         1    0.002    0.002    0.003    0.003 algorithms.py:457(isin)
#       701    0.002    0.000    0.014    0.000 base.py:3944(_get_indexer)
#       351    0.002    0.000    0.036    0.000 base.py:4327(reindex)
#      4879    0.002    0.000    0.003    0.000 base.py:908(__len__)
#       314    0.002    0.000    0.002    0.000 fast_binning.py:74(unpad)
#       301    0.002    0.000    0.011    0.000 <frozen codecs>:319(decode)
#      1909    0.002    0.000    0.004    0.000 common.py:1425(_is_dtype_type)
#       701    0.002    0.000    0.002    0.000 cast.py:550(maybe_promote)
#      1435    0.002    0.000    0.004    0.000 take.py:565(_take_preprocess_indexer_and_fill_value)
#       701    0.002    0.000    0.015    0.000 base.py:6320(_should_compare)
#      1053    0.002    0.000    0.005    0.000 base.py:5518(equals)
#       192    0.002    0.000    0.002    0.000 {pandas._libs.algos.take_2d_axis0_int64_int64}
#       506    0.002    0.000    0.002    0.000 {built-in method numpy.zeros}
#      1413    0.002    0.000    0.030    0.000 base.py:7512(ensure_index)
#       542    0.002    0.000    0.002    0.000 managers.py:931(from_blocks)
#       736    0.002    0.000    0.004    0.000 base.py:69(shape)
#       257    0.002    0.000    0.012    0.000 frame.py:3856(__getitem__)
#      5486    0.002    0.000    0.002    0.000 generic.py:548(_get_axis_number)
#       384    0.002    0.000    0.002    0.000 {built-in method pandas._libs.lib.is_bool_array}
#      1435    0.002    0.000    0.002    0.000 take.py:326(_get_take_nd_function)
#       350    0.002    0.000    0.301    0.001 indexing.py:1296(_getitem_iterable)
#       607    0.002    0.000    0.008    0.000 common.py:96(is_bool_indexer)
#       157    0.002    0.000    0.004    0.000 _methods.py:164(_mean)
#       314    0.001    0.000    0.079    0.000 basic.py:11(c2c)
#       253    0.001    0.000    0.020    0.000 generic.py:4296(_slice)
#      2109    0.001    0.000    0.002    0.000 indexing.py:1144(<genexpr>)
#       506    0.001    0.000    0.022    0.000 base.py:6684(get_slice_bound)
#       314    0.001    0.000    0.002    0.000 helper.py:80(_asfarray)
#       701    0.001    0.000    0.005    0.000 base.py:6250(_maybe_promote)
#       925    0.001    0.000    0.006    0.000 generic.py:335(_from_mgr)
#       253    0.001    0.000    0.010    0.000 base.py:5391(_getitem_slice)
#      3849    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_np_dtype}
#       323    0.001    0.000    0.008    0.000 cast.py:1147(maybe_infer_to_datetimelike)
#       446    0.001    0.000    0.006    0.000 indexing.py:931(_validate_tuple_indexer)
#       157    0.001    0.000    0.001    0.000 _methods.py:67(_count_reduce_items)
#       314    0.001    0.000    0.080    0.000 _backend.py:17(__ua_function__)
#      3308    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       129    0.001    0.000    0.002    0.000 managers.py:991(iget)
#       327    0.001    0.000    0.002    0.000 _dtype.py:344(_name_get)
#      1660    0.001    0.000    0.003    0.000 utils.py:62(is_list_like_indexer)
#       703    0.001    0.000    0.004    0.000 indexing.py:948(_is_nested_tuple_indexer)
#        96    0.001    0.000    0.067    0.001 generic.py:7023(fillna)
#       253    0.001    0.000    0.045    0.000 indexing.py:1395(_get_slice_axis)
#       927    0.001    0.000    0.001    0.000 {method 'add_index_reference' of 'pandas._libs.internals.BlockValuesRefs' objects}
#      2196    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#       795    0.001    0.000    0.007    0.000 frame.py:641(_constructor_from_mgr)
#      1990    0.001    0.000    0.001    0.000 __init__.py:33(using_copy_on_write)
#      1416    0.001    0.000    0.002    0.000 blocks.py:187(is_extension)
#      1406    0.001    0.000    0.003    0.000 indexing.py:2651(is_label_like)
#       479    0.001    0.000    0.001    0.000 warnings.py:466(__enter__)
#       674    0.001    0.000    0.002    0.000 blocks.py:2467(extend_blocks)
#       773    0.001    0.000    0.001    0.000 generic.py:6206(__setattr__)
#      1205    0.001    0.000    0.007    0.000 {method 'max' of 'numpy.ndarray' objects}
#       446    0.001    0.000    0.003    0.000 indexing.py:1247(_multi_take_opportunity)
#      4757    0.001    0.000    0.001    0.000 {built-in method builtins.issubclass}
#       701    0.001    0.000    0.001    0.000 base.py:3989(_check_indexing_method)
#      2207    0.001    0.000    0.003    0.000 base.py:71(<genexpr>)
#      1208    0.001    0.000    0.001    0.000 common.py:131(<lambda>)
#       386    0.001    0.000    0.002    0.000 blocks.py:2388(new_block)
#       253    0.001    0.000    0.023    0.000 base.py:6767(slice_locs)
#         1    0.001    0.001    0.003    0.003 fast_binning.py:127(conditional_breakpoints)
#       639    0.001    0.000    0.016    0.000 base.py:3762(get_loc)
#       929    0.001    0.000    0.001    0.000 flags.py:53(__init__)
#       350    0.001    0.000    0.003    0.000 algorithms.py:1211(take)
#       350    0.001    0.000    0.109    0.000 indexing.py:1494(_get_listlike_indexer)
#      2196    0.001    0.000    0.002    0.000 <frozen abc>:117(__instancecheck__)
#       100    0.001    0.000    0.001    0.000 cast.py:1724(np_can_hold_element)
#       506    0.001    0.000    0.004    0.000 base.py:6638(_maybe_cast_slice_bound)
#       330    0.001    0.000    0.003    0.000 numeric.py:290(full)
#      1149    0.001    0.000    0.001    0.000 common.py:306(is_null_slice)
#      1149    0.001    0.000    0.003    0.000 indexing.py:909(_expand_ellipsis)
#       701    0.001    0.000    0.001    0.000 base.py:7642(_unpack_nested_dtype)
#       350    0.001    0.000    0.001    0.000 {method 'take' of 'numpy.ndarray' objects}
#       257    0.001    0.000    0.008    0.000 frame.py:4405(_get_item_cache)
#      2109    0.001    0.000    0.001    0.000 indexing.py:2685(<genexpr>)
#       701    0.001    0.000    0.002    0.000 common.py:137(is_object_dtype)
#       288    0.001    0.000    0.001    0.000 blocks.py:497(_maybe_downcast)
#      2109    0.001    0.000    0.001    0.000 indexing.py:955(<genexpr>)
#       799    0.001    0.000    0.001    0.000 frame.py:952(axes)
#       487    0.001    0.000    0.003    0.000 <__array_function__ internals>:177(copyto)
#       224    0.001    0.000    0.032    0.000 fast_binning.py:254(<genexpr>)
#       927    0.001    0.000    0.001    0.000 flags.py:89(allows_duplicate_labels)
#      1306    0.001    0.000    0.001    0.000 indexing.py:289(loc)
#       351    0.001    0.000    0.001    0.000 managers.py:2268(_preprocess_slice_or_indexer)
#      1053    0.001    0.000    0.001    0.000 base.py:790(is_)
#      2109    0.001    0.000    0.001    0.000 indexing.py:1143(<genexpr>)
#       261    0.001    0.000    0.001    0.000 base.py:5299(__contains__)
#       701    0.001    0.000    0.006    0.000 base.py:6342(_is_comparable_dtype)
#       293    0.001    0.000    0.010    0.000 missing.py:184(_isna)
#       157    0.001    0.000    0.004    0.000 numeric.py:77(zeros_like)
#      3447    0.001    0.000    0.001    0.000 indexing.py:915(<genexpr>)
#      1667    0.001    0.000    0.001    0.000 common.py:367(apply_if_callable)
#       701    0.001    0.000    0.002    0.000 common.py:1366(_is_dtype)
#       288    0.001    0.000    0.004    0.000 putmask.py:101(validate_putmask)
#      1853    0.001    0.000    0.001    0.000 {built-in method __new__ of type object at 0x860f60}
#      3538    0.001    0.000    0.001    0.000 {pandas._libs.algos.ensure_platform_int}
#       519    0.001    0.000    0.002    0.000 base.py:7607(maybe_extract_name)
#       350    0.001    0.000    0.047    0.000 base.py:6076(get_indexer_for)
#       296    0.001    0.000    0.001    0.000 blocks.py:2317(maybe_coerce_values)
#       253    0.001    0.000    0.024    0.000 base.py:6557(slice_indexer)
#      2843    0.001    0.000    0.001    0.000 {pandas._libs.lib.is_iterator}
#       620    0.001    0.000    0.001    0.000 construction.py:484(ensure_wrapped_if_datetimelike)
#         1    0.001    0.001    2.054    2.054 <string>:1(<module>)
#      1205    0.001    0.000    0.005    0.000 _methods.py:39(_amax)
#       801    0.001    0.000    0.001    0.000 {built-in method pandas._libs.missing.checknull}
#       604    0.001    0.000    0.001    0.000 generic.py:568(_get_block_manager_axis)
#       701    0.001    0.000    0.018    0.000 base.py:6618(_maybe_cast_listlike_indexer)
#       448    0.001    0.000    0.013    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      1149    0.001    0.000    0.001    0.000 indexing.py:966(_validate_key_length)
#       734    0.001    0.000    0.001    0.000 {built-in method builtins.max}
#       129    0.001    0.000    0.007    0.000 frame.py:3779(_ixs)
#      1753    0.001    0.000    0.001    0.000 base.py:6238(_index_as_unique)
#      2109    0.001    0.000    0.001    0.000 indexing.py:2694(<genexpr>)
#       396    0.001    0.000    0.001    0.000 blocks.py:2346(get_block_type)
#        96    0.001    0.000    0.001    0.000 {pandas._libs.ops_dispatch.maybe_dispatch_ufunc_to_dunder_op}
#       648    0.001    0.000    0.001    0.000 common.py:1322(is_ea_or_datetimelike_dtype)
#       257    0.001    0.000    0.013    0.000 generic.py:4094(xs)
#       359    0.001    0.000    0.001    0.000 {built-in method builtins.sorted}
#       258    0.001    0.000    0.001    0.000 base.py:5349(__getitem__)
#        96    0.001    0.000    0.001    0.000 _validators.py:271(validate_fillna_kwargs)
#       479    0.001    0.000    0.001    0.000 warnings.py:487(__exit__)
#       192    0.001    0.000    0.022    0.000 frame.py:1832(to_numpy)
#      2864    0.001    0.000    0.001    0.000 base.py:5126(_values)
#      1786    0.001    0.000    0.001    0.000 generic.py:659(ndim)
#       479    0.001    0.000    0.001    0.000 warnings.py:440(__init__)
#       192    0.001    0.000    0.002    0.000 blocks.py:639(copy)
#       290    0.001    0.000    0.001    0.000 blocks.py:226(fill_value)
#       498    0.001    0.000    0.001    0.000 {built-in method numpy.array}
#         1    0.001    0.001    0.010    0.010 c_parser_wrapper.py:355(_concatenate_chunks)
#       892    0.001    0.000    0.001    0.000 indexing.py:1265(<genexpr>)
#       359    0.001    0.000    0.001    0.000 construction.py:673(_sanitize_ndim)
#       780    0.001    0.000    0.001    0.000 inference.py:334(is_hashable)
#       260    0.001    0.000    0.001    0.000 base.py:458(_engine_type)
#       257    0.001    0.000    0.002    0.000 managers.py:1956(external_values)
#       192    0.001    0.000    0.001    0.000 base.py:366(ensure_np_dtype)
#       927    0.001    0.000    0.001    0.000 base.py:830(_reset_identity)
#       288    0.001    0.000    0.001    0.000 blocks.py:203(_can_hold_na)
#        96    0.000    0.000    0.022    0.000 generic.py:2098(__array_ufunc__)
#       129    0.000    0.000    0.003    0.000 frame.py:4387(_box_col_values)
#      1208    0.000    0.000    0.000    0.000 common.py:126(_classes_and_not_datetimelike)
#       323    0.000    0.000    0.006    0.000 base.py:2723(inferred_type)
#       324    0.000    0.000    0.000    0.000 base.py:573(_ensure_array)
#       257    0.000    0.000    0.001    0.000 blocks.py:2586(external_values)
#       703    0.000    0.000    0.001    0.000 contextlib.py:434(__exit__)
#       290    0.000    0.000    0.001    0.000 missing.py:639(na_value_for_dtype)
#        96    0.000    0.000    0.002    0.000 arraylike.py:342(_reconstruct)
#       293    0.000    0.000    0.001    0.000 blocks.py:192(_can_consolidate)
#       350    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#      1854    0.000    0.000    0.000    0.000 generic.py:393(flags)
#       351    0.000    0.000    0.001    0.000 base.py:4444(_maybe_preserve_names)
#       700    0.000    0.000    0.001    0.000 managers.py:230(is_single_block)
#       448    0.000    0.000    0.013    0.000 _methods.py:47(_sum)
#       324    0.000    0.000    0.000    0.000 base.py:591(_dtype_to_subclass)
#       289    0.000    0.000    0.003    0.000 {method 'any' of 'numpy.ndarray' objects}
#       288    0.000    0.000    0.004    0.000 blocks.py:387(_split_op_result)
#       253    0.000    0.000    0.001    0.000 generic.py:4314(_set_is_copy)
#       301    0.000    0.000    0.000    0.000 <frozen codecs>:331(getstate)
#       157    0.000    0.000    0.004    0.000 <__array_function__ internals>:177(zeros_like)
#       384    0.000    0.000    0.001    0.000 putmask.py:115(extract_bool_array)
#       263    0.000    0.000    0.000    0.000 common.py:1025(needs_i8_conversion)
#       460    0.000    0.000    0.002    0.000 {built-in method builtins.all}
#         4    0.000    0.000    0.000    0.000 {method 'astype' of 'numpy.ndarray' objects}
#      1121    0.000    0.000    0.000    0.000 {pandas._libs.lib.item_from_zerodim}
#      2244    0.000    0.000    0.000    0.000 {built-in method builtins.callable}
#       701    0.000    0.000    0.001    0.000 common.py:1390(_get_dtype)
#       157    0.000    0.000    0.005    0.000 {method 'mean' of 'numpy.ndarray' objects}
#       350    0.000    0.000    0.000    0.000 generic.py:556(_get_axis_name)
#       361    0.000    0.000    0.000    0.000 construction.py:419(extract_array)
#       385    0.000    0.000    0.000    0.000 _validators.py:226(validate_bool_kwarg)
#       351    0.000    0.000    0.001    0.000 base.py:4440(_wrap_reindex_result)
#         6    0.000    0.000    0.000    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      1408    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#       314    0.000    0.000    0.000    0.000 {method 'newbyteorder' of 'numpy.dtype' objects}
#       350    0.000    0.000    0.001    0.000 inference.py:195(is_array_like)
#       351    0.000    0.000    0.001    0.000 base.py:7571(ensure_has_len)
#       701    0.000    0.000    0.000    0.000 common.py:1107(<lambda>)
#       257    0.000    0.000    0.013    0.000 indexing.py:1341(_get_label)
#         1    0.000    0.000    0.000    0.000 {method 'dot' of 'numpy.ndarray' objects}
#       192    0.000    0.000    0.001    0.000 base.py:1671(name)
#       157    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(empty_like)
#       930    0.000    0.000    0.000    0.000 base.py:973(dtype)
#       703    0.000    0.000    0.000    0.000 contextlib.py:428(__init__)
#       314    0.000    0.000    0.000    0.000 helper.py:100(_datacopied)
#       927    0.000    0.000    0.000    0.000 generic.py:358(attrs)
#        96    0.000    0.000    0.063    0.001 base.py:167(fillna)
#       356    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.088    0.088 construction.py:96(arrays_to_mgr)
#       907    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       701    0.000    0.000    0.000    0.000 common.py:123(<lambda>)
#       293    0.000    0.000    0.010    0.000 missing.py:101(isna)
#       359    0.000    0.000    0.000    0.000 construction.py:712(_sanitize_str_dtypes)
#       314    0.000    0.000    0.003    0.000 {method 'min' of 'numpy.ndarray' objects}
#       194    0.000    0.000    0.002    0.000 {method 'all' of 'numpy.ndarray' objects}
#       128    0.000    0.000    0.011    0.000 <__array_function__ internals>:177(searchsorted)
#      1055    0.000    0.000    0.000    0.000 base.py:1656(name)
#         1    0.000    0.000    0.000    0.000 base.py:2208(is_monotonic_increasing)
#       323    0.000    0.000    0.000    0.000 __init__.py:43(using_pyarrow_string_dtype)
#       704    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_float}
#       193    0.000    0.000    0.000    0.000 common.py:514(is_string_or_object_np_dtype)
#       129    0.000    0.000    0.002    0.000 frame.py:656(_constructor_sliced_from_mgr)
#       870    0.000    0.000    0.000    0.000 blocks.py:583(dtype)
#       129    0.000    0.000    0.001    0.000 series.py:1372(_set_as_cached)
#        30    0.000    0.000    0.009    0.000 concat.py:52(concat_compat)
#       128    0.000    0.000    0.010    0.000 fromnumeric.py:1345(searchsorted)
#      1041    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        96    0.000    0.000    0.021    0.000 expressions.py:177(_where_numexpr)
#       257    0.000    0.000    0.001    0.000 blocks.py:222(external_values)
#       158    0.000    0.000    0.003    0.000 frame.py:12210(values)
#       927    0.000    0.000    0.000    0.000 flags.py:57(allows_duplicate_labels)
#       314    0.000    0.000    0.001    0.000 helper.py:161(_workers)
#        96    0.000    0.000    0.021    0.000 expressions.py:172(_where_standard)
#        96    0.000    0.000    0.020    0.000 <__array_function__ internals>:177(where)
#       576    0.000    0.000    0.000    0.000 blocks.py:2245(get_values)
#       134    0.000    0.000    0.010    0.000 fromnumeric.py:51(_wrapfunc)
#         5    0.000    0.000    0.002    0.000 index_tricks.py:329(__getitem__)
#       701    0.000    0.000    0.000    0.000 common.py:121(classes)
#       289    0.000    0.000    0.002    0.000 _methods.py:55(_any)
#       483    0.000    0.000    0.000    0.000 managers.py:169(blknos)
#         4    0.000    0.000    0.002    0.000 base.py:6895(insert)
#       314    0.000    0.000    0.000    0.000 helper.py:150(_normalization)
#       327    0.000    0.000    0.000    0.000 _dtype.py:330(_name_includes_bit_suffix)
#       314    0.000    0.000    0.003    0.000 _methods.py:43(_amin)
#        96    0.000    0.000    0.001    0.000 blocks.py:232(_standardize_fill_value)
#      1409    0.000    0.000    0.000    0.000 base.py:363(ndim)
#       326    0.000    0.000    0.001    0.000 base.py:2755(_is_multi)
#       253    0.000    0.000    0.000    0.000 {method '_update_from_sliced' of 'pandas._libs.index.IndexEngine' objects}
#       257    0.000    0.000    0.002    0.000 series.py:708(values)
#       959    0.000    0.000    0.000    0.000 {built-in method _warnings._filters_mutated}
#         1    0.000    0.000    2.054    2.054 {built-in method builtins.exec}
#       796    0.000    0.000    0.000    0.000 managers.py:896(__init__)
#        96    0.000    0.000    0.003    0.000 <__array_function__ internals>:177(ravel_multi_index)
#        47    0.000    0.000    0.035    0.001 <__array_function__ internals>:177(concatenate)
#       192    0.000    0.000    0.000    0.000 base.py:914(__array__)
#        96    0.000    0.000    0.001    0.000 blocks.py:1425(<listcomp>)
#       483    0.000    0.000    0.000    0.000 managers.py:185(blklocs)
#       129    0.000    0.000    0.000    0.000 blocks.py:1007(iget)
#       327    0.000    0.000    0.000    0.000 _dtype.py:24(_kind_name)
#         1    0.000    0.000    0.029    0.029 managers.py:2137(_form_blocks)
#       702    0.000    0.000    0.000    0.000 missing.py:971(clean_reindex_fill_method)
#      1145    0.000    0.000    0.000    0.000 base.py:6611(_maybe_cast_indexer)
#       194    0.000    0.000    0.002    0.000 _methods.py:61(_all)
#       100    0.000    0.000    0.001    0.000 missing.py:693(is_valid_na_for_dtype)
#       580    0.000    0.000    0.000    0.000 blocks.py:239(mgr_locs)
#        96    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1207(_handle_fromlist)
#         1    0.000    0.000    0.006    0.006 common.py:652(get_handle)
#         4    0.000    0.000    0.000    0.000 function_base.py:5250(insert)
#       258    0.000    0.000    0.000    0.000 common.py:149(cast_scalar_indexer)
#        96    0.000    0.000    0.000    0.000 arraylike.py:298(<listcomp>)
#         6    0.000    0.000    0.001    0.000 base.py:2292(is_unique)
#       353    0.000    0.000    0.000    0.000 {method 'keys' of 'dict' objects}
#        30    0.000    0.000    0.000    0.000 c_parser_wrapper.py:367(<listcomp>)
#        96    0.000    0.000    0.021    0.000 expressions.py:246(where)
#       129    0.000    0.000    0.001    0.000 frame.py:653(_sliced_from_mgr)
#         1    0.000    0.000    0.016    0.016 readers.py:1403(__init__)
#       487    0.000    0.000    0.000    0.000 multiarray.py:1079(copyto)
#        96    0.000    0.000    0.000    0.000 expressions.py:76(_can_use_numexpr)
#        10    0.000    0.000    0.000    0.000 numerictypes.py:573(_can_coerce_all)
#        96    0.000    0.000    0.000    0.000 cast.py:921(_maybe_infer_dtype_type)
#        96    0.000    0.000    0.002    0.000 arraylike.py:335(reconstruct)
#         4    0.000    0.000    0.005    0.001 frame.py:4065(__setitem__)
#         4    0.000    0.000    0.003    0.001 frame.py:4260(_set_item_mgr)
#         1    0.000    0.000    0.015    0.015 readers.py:1673(_make_engine)
#        96    0.000    0.000    0.000    0.000 putmask.py:129(setitem_datetimelike_compat)
#       350    0.000    0.000    0.000    0.000 base.py:1168(_maybe_disallow_fill)
#       758    0.000    0.000    0.000    0.000 typing.py:2256(cast)
#       387    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_bool}
#       703    0.000    0.000    0.000    0.000 contextlib.py:431(__enter__)
#         1    0.000    0.000    1.272    1.272 readers.py:574(_read)
#       284    0.000    0.000    0.000    0.000 {method 'pop' of 'dict' objects}
#       165    0.000    0.000    0.000    0.000 {built-in method numpy.core._multiarray_umath.normalize_axis_index}
#       3/2    0.000    0.000    0.002    0.001 series.py:371(__init__)
#       132    0.000    0.000    0.000    0.000 managers.py:1799(__init__)
#       253    0.000    0.000    0.000    0.000 indexing.py:2665(need_slice)
#         4    0.000    0.000    0.002    0.001 managers.py:1311(insert)
#       359    0.000    0.000    0.000    0.000 construction.py:732(_maybe_repeat)
#         1    0.000    0.000    0.091    0.091 frame.py:668(__init__)
#       359    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_integer}
#         1    0.000    0.000    0.001    0.001 construction.py:596(_homogenize)
#         1    0.000    0.000    1.272    1.272 readers.py:848(read_csv)
#         1    0.000    0.000    0.090    0.090 construction.py:423(dict_to_mgr)
#         1    0.000    0.000    1.163    1.163 c_parser_wrapper.py:222(read)
#         1    0.000    0.000    1.254    1.254 readers.py:1732(read)
#         1    0.000    0.000    0.000    0.000 base_parser.py:190(_validate_parse_dates_presence)
#       177    0.000    0.000    0.000    0.000 {built-in method numpy.asanyarray}
#         1    0.000    0.000    0.003    0.003 base_parser.py:669(_infer_types)
#         1    0.000    0.000    0.000    0.000 base_parser.py:114(__init__)
#         1    0.000    0.000    0.000    0.000 readers.py:1513(_clean_options)
#         6    0.000    0.000    0.000    0.000 blocks.py:2375(new_block_2d)
#         7    0.000    0.000    0.000    0.000 inference.py:273(is_dict_like)
#         5    0.000    0.000    0.000    0.000 numerictypes.py:597(find_common_type)
#         4    0.000    0.000    0.000    0.000 numeric.py:1411(moveaxis)
#        30    0.000    0.000    0.000    0.000 c_parser_wrapper.py:369(<setcomp>)
#       192    0.000    0.000    0.000    0.000 managers.py:335(<dictcomp>)
#         8    0.000    0.000    0.000    0.000 numeric.py:1348(normalize_axis_tuple)
#         4    0.000    0.000    0.004    0.001 frame.py:4293(_set_item)
#       192    0.000    0.000    0.000    0.000 arraylike.py:297(<genexpr>)
#         2    0.000    0.000    0.000    0.000 common.py:1587(pandas_dtype)
#         1    0.000    0.000    0.000    0.000 readers.py:1455(_get_options_with_defaults)
#       131    0.000    0.000    0.000    0.000 managers.py:1902(_block)
#         4    0.000    0.000    0.000    0.000 managers.py:1361(_insert_update_mgr_locs)
#         3    0.000    0.000    0.000    0.000 common.py:173(_expand_user)
#        96    0.000    0.000    0.000    0.000 generic.py:6933(_deprecate_downcast)
#         1    0.000    0.000    0.003    0.003 base_parser.py:461(_agg_index)
#        96    0.000    0.000    0.000    0.000 arraylike.py:415(_standardize_out_kwarg)
#         4    0.000    0.000    0.002    0.000 frame.py:5018(_sanitize_column)
#       157    0.000    0.000    0.000    0.000 multiarray.py:84(empty_like)
#        13    0.000    0.000    0.000    0.000 fromnumeric.py:3152(ndim)
#         4    0.000    0.000    0.000    0.000 _asarray.py:31(require)
#        22    0.000    0.000    0.000    0.000 managers.py:1351(<genexpr>)
#        44    0.000    0.000    0.000    0.000 numerictypes.py:582(<listcomp>)
#         1    0.000    0.000    0.057    0.057 managers.py:2207(_consolidate)
#         1    0.000    0.000    0.000    0.000 common.py:289(_get_filepath_or_buffer)
#       158    0.000    0.000    0.000    0.000 base.py:1953(nlevels)
#         4    0.000    0.000    0.001    0.000 base.py:673(_with_infer)
#       157    0.000    0.000    0.000    0.000 numeric.py:73(_zeros_like_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method '_rebuild_blknos_and_blklocs' of 'pandas._libs.internals.BlockManager' objects}
#         1    0.000    0.000    0.000    0.000 base.py:7472(ensure_index_from_sequences)
#        13    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ndim)
#         8    0.000    0.000    0.000    0.000 function_base.py:5444(append)
#        35    0.000    0.000    0.000    0.000 common.py:556(require_length_match)
#         2    0.000    0.000    0.000    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#        30    0.000    0.000    0.000    0.000 concat.py:73(<listcomp>)
#        96    0.000    0.000    0.000    0.000 multiarray.py:345(where)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:38(_wrapit)
#         2    0.000    0.000    0.001    0.000 numeric.py:578(argwhere)
#         4    0.000    0.000    0.000    0.000 base.py:5271(_validate_fill_value)
#       128    0.000    0.000    0.000    0.000 fromnumeric.py:1341(_searchsorted_dispatcher)
#        30    0.000    0.000    0.000    0.000 c_parser_wrapper.py:370(<setcomp>)
#        96    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         4    0.000    0.000    0.000    0.000 managers.py:1371(_insert_update_blklocs_and_blknos)
#        30    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#         1    0.000    0.000    0.087    0.087 managers.py:2068(create_block_manager_from_column_arrays)
#         4    0.000    0.000    0.000    0.000 managers.py:2259(_fast_count_smallints)
#         4    0.000    0.000    0.000    0.000 cast.py:1544(construct_1d_object_array_from_listlike)
#         1    0.000    0.000    0.000    0.000 algorithms.py:1328(searchsorted)
#         1    0.000    0.000    0.003    0.003 base_parser.py:361(_make_index)
#         1    0.000    0.000    0.000    0.000 common.py:1223(dedup_names)
#         2    0.000    0.000    0.000    0.000 common.py:1155(_is_binary_mode)
#        29    0.000    0.000    0.000    0.000 managers.py:2124(_grouping_func)
#         1    0.000    0.000    0.003    0.003 readers.py:1450(close)
#         1    0.000    0.000    0.002    0.002 series.py:524(_init_dict)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:201(_set_noconvert_columns)
#        50    0.000    0.000    0.000    0.000 base.py:3794(<genexpr>)
#         1    0.000    0.000    0.003    0.003 common.py:121(close)
#         1    0.000    0.000    0.001    0.001 generic.py:5525(_reindex_axes)
#         2    0.000    0.000    0.000    0.000 common.py:1194(is_potential_multi_index)
#         4    0.000    0.000    0.000    0.000 _asarray.py:112(<setcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:487(<listcomp>)
#         1    0.000    0.000    0.057    0.057 managers.py:1744(_consolidate_inplace)
#         3    0.000    0.000    0.000    0.000 config.py:127(_get_single_key)
#         1    0.000    0.000    0.000    0.000 common.py:538(infer_compression)
#         2    0.000    0.000    0.000    0.000 managers.py:1825(from_array)
#         1    0.000    0.000    0.000    0.000 managers.py:1740(<listcomp>)
#         1    0.000    0.000    0.000    0.000 parse.py:374(urlparse)
#         5    0.000    0.000    0.000    0.000 numerictypes.py:649(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:861(_do_date_conversions)
#         1    0.000    0.000    0.001    0.001 generic.py:5266(reindex)
#         1    0.000    0.000    0.000    0.000 series.py:6131(any)
#         2    0.000    0.000    0.025    0.012 shape_base.py:223(vstack)
#        96    0.000    0.000    0.000    0.000 multiarray.py:968(ravel_multi_index)
#        21    0.000    0.000    0.000    0.000 inference.py:300(<genexpr>)
#         4    0.000    0.000    0.000    0.000 blocks.py:2483(ensure_block_shape)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1026(_clean_index_names)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:1781(ravel)
#         3    0.000    0.000    0.000    0.000 cast.py:119(maybe_convert_platform)
#         3    0.000    0.000    0.000    0.000 config.py:145(_get_option)
#         4    0.000    0.000    0.000    0.000 blocks.py:198(_consolidate_key)
#        33    0.000    0.000    0.000    0.000 common.py:1255(is_1d_only_ea_dtype)
#         3    0.000    0.000    0.000    0.000 <frozen posixpath>:229(expanduser)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:194(close)
#         3    0.000    0.000    0.000    0.000 generic.py:760(_set_axis)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.sum}
#         1    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.isnaobj}
#         8    0.000    0.000    0.000    0.000 numeric.py:1398(<listcomp>)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(insert)
#         1    0.000    0.000    0.000    0.000 base_parser.py:392(_get_simple_index)
#        11    0.000    0.000    0.000    0.000 {method 'ravel' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 readers.py:1925(_refine_defaults_read)
#         3    0.000    0.000    0.000    0.000 series.py:703(name)
#         4    0.000    0.000    0.000    0.000 generic.py:4337(_check_setitem_copy)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.locals}
#         3    0.000    0.000    0.008    0.003 <__array_function__ internals>:177(norm)
#         3    0.000    0.000    0.000    0.000 config.py:633(_get_root)
#         1    0.000    0.000    0.000    0.000 base_parser.py:600(_set_noconvert_dtype_columns)
#        47    0.000    0.000    0.000    0.000 multiarray.py:152(concatenate)
#         1    0.000    0.000    0.000    0.000 <string>:1(<lambda>)
#         2    0.000    0.000    0.000    0.000 generic.py:487(_validate_dtype)
#         4    0.000    0.000    0.000    0.000 series.py:653(name)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(append)
#         2    0.000    0.000    0.001    0.000 <__array_function__ internals>:177(argwhere)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1038(argsort)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:212(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 shape_base.py:81(atleast_2d)
#         8    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(ravel)
#         1    0.000    0.000    0.000    0.000 {method 'close' of 'pandas._libs.parsers.TextReader' objects}
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(argsort)
#         1    0.000    0.000    0.001    0.001 series.py:4960(reindex)
#         8    0.000    0.000    0.000    0.000 generic.py:638(_info_axis)
#         1    0.000    0.000    0.000    0.000 common.py:145(is_url)
#         5    0.000    0.000    0.000    0.000 managers.py:1960(internal_values)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:309(__init__)
#         1    0.000    0.000    0.000    0.000 series.py:6090(_reduce)
#         4    0.000    0.000    0.000    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#         6    0.000    0.000    0.000    0.000 config.py:647(_get_deprecated_option)
#         2    0.000    0.000    0.000    0.000 managers.py:2233(<listcomp>)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.algos.take_1d_object_object}
#         8    0.000    0.000    0.000    0.000 managers.py:2212(<lambda>)
#         3    0.000    0.000    0.000    0.000 config.py:271(__call__)
#         2    0.000    0.000    0.000    0.000 common.py:233(stringify_path)
#         2    0.000    0.000    0.000    0.000 generic.py:5509(<genexpr>)
#         4    0.000    0.000    0.000    0.000 common.py:1219(<genexpr>)
#         1    0.000    0.000    0.000    0.000 common.py:192(validate_header_arg)
#         4    0.000    0.000    0.000    0.000 frame.py:4364(_ensure_valid_index)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(moveaxis)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(transpose)
#         1    0.000    0.000    0.000    0.000 managers.py:1734(_consolidate_check)
#         4    0.000    0.000    0.000    0.000 numerictypes.py:356(issubdtype)
#        30    0.000    0.000    0.000    0.000 {method 'pop' of 'set' objects}
#         1    0.000    0.000    0.000    0.000 base_parser.py:1404(_validate_parse_dates_arg)
#         1    0.000    0.000    0.000    0.000 warnings.py:181(_add_filter)
#         1    0.000    0.000    0.000    0.000 cast.py:1359(np_find_common_type)
#         4    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(bincount)
#         1    0.000    0.000    0.000    0.000 common.py:277(is_fsspec_url)
#         1    0.000    0.000    0.000    0.000 base.py:836(__iter__)
#         2    0.000    0.000    0.000    0.000 inference.py:105(is_file_like)
#         1    0.000    0.000    0.000    0.000 base.py:5609(identical)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:330(<dictcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:1335(searchsorted)
#         3    0.000    0.000    0.000    0.000 managers.py:225(set_axis)
#         4    0.000    0.000    0.000    0.000 frame.py:1542(__len__)
#         3    0.000    0.000    0.000    0.000 generic.py:6189(__getattr__)
#         1    0.000    0.000    0.000    0.000 warnings.py:165(simplefilter)
#         1    0.000    0.000    0.000    0.000 series.py:581(_constructor_from_mgr)
#         5    0.000    0.000    0.000    0.000 series.py:750(_values)
#         3    0.000    0.000    0.000    0.000 base.py:73(_validate_set_axis)
#        13    0.000    0.000    0.000    0.000 fromnumeric.py:3148(_ndim_dispatcher)
#         1    0.000    0.000    0.003    0.003 readers.py:1782(__exit__)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1892(nonzero)
#         2    0.000    0.000    0.025    0.012 <__array_function__ internals>:177(vstack)
#         8    0.000    0.000    0.000    0.000 numerictypes.py:282(issubclass_)
#         2    0.000    0.000    0.000    0.000 base.py:2773(_na_value)
#         1    0.000    0.000    0.000    0.000 base_parser.py:278(_extract_multi_indexer_columns)
#         1    0.000    0.000    0.000    0.000 getlimits.py:668(__init__)
#         1    0.000    0.000    0.000    0.000 nanops.py:482(nanany)
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:213(<listcomp>)
#         3    0.000    0.000    0.000    0.000 config.py:686(_warn_if_deprecated)
#         1    0.000    0.000    0.000    0.000 parse.py:119(_coerce_args)
#         1    0.000    0.000    0.000    0.000 base_parser.py:692(<listcomp>)
#         2    0.000    0.000    0.000    0.000 shape_base.py:218(_vhstack_dispatcher)
#         3    0.000    0.000    0.000    0.000 {method 'copy' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 base.py:6670(_searchsorted_monotonic)
#         1    0.000    0.000    0.000    0.000 managers.py:1812(from_blocks)
#         1    0.000    0.000    0.000    0.000 {method 'match' of 're.Pattern' objects}
#         3    0.000    0.000    0.000    0.000 config.py:615(_select_options)
#         1    0.000    0.000    0.000    0.000 readers.py:1502(_check_file_or_buffer)
#         1    0.000    0.000    0.000    0.000 missing.py:305(_isna_string_dtype)
#         5    0.000    0.000    0.000    0.000 managers.py:235(items)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(nonzero)
#         3    0.000    0.000    0.000    0.000 common.py:1562(validate_all_hashable)
#         1    0.000    0.000    0.000    0.000 copy.py:66(copy)
#         2    0.000    0.000    0.000    0.000 {pandas._libs.lib.is_all_arraylike}
#         6    0.000    0.000    0.000    0.000 common.py:1581(<genexpr>)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1247(_process_date_conversion)
#         1    0.000    0.000    0.000    0.000 managers.py:1726(is_consolidated)
#         2    0.000    0.000    0.000    0.000 {method 'remove' of 'list' objects}
#         5    0.000    0.000    0.000    0.000 {method 'insert' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:326(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:196(mgr_to_mgr)
#         3    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         4    0.000    0.000    0.000    0.000 construction.py:665(_sanitize_non_ordered)
#         2    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(atleast_2d)
#         4    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         2    0.000    0.000    0.000    0.000 base_parser.py:254(_has_complex_date_col)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:601(transpose)
#         1    0.000    0.000    0.000    0.000 base.py:510(find)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup}
#         1    0.000    0.000    0.000    0.000 generic.py:8402(isna)
#         1    0.000    0.000    0.000    0.000 base_parser.py:349(_maybe_make_multi_index_columns)
#         1    0.000    0.000    0.000    0.000 common.py:296(maybe_iterable_to_list)
#         9    0.000    0.000    0.000    0.000 {method 'lower' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 base_parser.py:443(_clean_mapping)
#         9    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 common.py:1107(_maybe_memory_map)
#         4    0.000    0.000    0.000    0.000 numeric.py:1473(<listcomp>)
#         1    0.000    0.000    0.000    0.000 base.py:61(__len__)
#         1    0.000    0.000    0.000    0.000 enum.py:193(__get__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:1113(_make_date_converter)
#         4    0.000    0.000    0.000    0.000 {method 'format' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 numerictypes.py:650(<listcomp>)
#         1    0.000    0.000    0.000    0.000 series.py:5478(isna)
#         1    0.000    0.000    0.000    0.000 <string>:2(__init__)
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(result_type)
#         2    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#         6    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 c_parser_wrapper.py:392(ensure_dtype_objs)
#         8    0.000    0.000    0.000    0.000 function_base.py:5440(_append_dispatcher)
#         8    0.000    0.000    0.000    0.000 {built-in method _operator.index}
#         3    0.000    0.000    0.000    0.000 config.py:674(_translate_key)
#         4    0.000    0.000    0.000    0.000 function_base.py:5246(_insert_dispatcher)
#         1    0.000    0.000    0.000    0.000 readers.py:1850(_clean_na_values)
#         3    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method sys.getfilesystemencoding}
#         4    0.000    0.000    0.000    0.000 base_parser.py:1425(is_index_col)
#         1    0.000    0.000    0.000    0.000 <frozen codecs>:260(__init__)
#         8    0.000    0.000    0.000    0.000 fromnumeric.py:1777(_ravel_dispatcher)
#         2    0.000    0.000    0.000    0.000 managers.py:2242(<listcomp>)
#         1    0.000    0.000    0.000    0.000 construction.py:743(_try_cast)
#         1    0.000    0.000    0.000    0.000 {method 'update' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 shape_base.py:207(_arrays_for_stack_dispatcher)
#         1    0.000    0.000    0.000    0.000 common.py:503(get_compression_method)
#         2    0.000    0.000    0.000    0.000 base.py:691(_constructor)
#         2    0.000    0.000    0.000    0.000 numeric.py:574(_argwhere_dispatcher)
#         1    0.000    0.000    0.000    0.000 base_parser.py:263(_should_parse_dates)
#         2    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 getlimits.py:679(min)
#         2    0.000    0.000    0.000    0.000 {method 'conj' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 getlimits.py:692(max)
#         1    0.000    0.000    0.000    0.000 {built-in method _codecs.lookup_error}
#         2    0.000    0.000    0.000    0.000 base.py:538(<genexpr>)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1034(_argsort_dispatcher)
#         1    0.000    0.000    0.000    0.000 base.py:4310(_validate_can_reindex)
#         1    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#         1    0.000    0.000    0.000    0.000 base_parser.py:394(ix)
#         3    0.000    0.000    0.000    0.000 {built-in method posix.fspath}
#         4    0.000    0.000    0.000    0.000 numeric.py:1407(_moveaxis_dispatcher)
#         1    0.000    0.000    0.000    0.000 {method 'reverse' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 series.py:821(__len__)
#         1    0.000    0.000    0.000    0.000 base_parser.py:234(<setcomp>)
#         4    0.000    0.000    0.000    0.000 multiarray.py:891(bincount)
#         1    0.000    0.000    0.000    0.000 readers.py:2055(_extract_dialect)
#         1    0.000    0.000    0.000    0.000 algorithms.py:217(_ensure_arraylike)
#         3    0.000    0.000    0.000    0.000 linalg.py:2338(_norm_dispatcher)
#         1    0.000    0.000    0.000    0.000 _validators.py:450(check_dtype_backend)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:597(_transpose_dispatcher)
#         1    0.000    0.000    0.000    0.000 readers.py:2153(_validate_skipfooter)
#         1    0.000    0.000    0.000    0.000 {method 'join' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 function.py:64(__call__)
#         1    0.000    0.000    0.000    0.000 enum.py:1249(value)
#         1    0.000    0.000    0.000    0.000 {method 'encode' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 series.py:1381(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 base_parser.py:246(<listcomp>)
#         2    0.000    0.000    0.000    0.000 readers.py:518(validate_integer)
#         2    0.000    0.000    0.000    0.000 fromnumeric.py:1888(_nonzero_dispatcher)
#         1    0.000    0.000    0.000    0.000 base_parser.py:883(_check_data_length)
#         1    0.000    0.000    0.000    0.000 base_parser.py:976(_validate_usecols_arg)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.ord}
#         2    0.000    0.000    0.000    0.000 managers.py:1790(ndim)
#         1    0.000    0.000    0.000    0.000 readers.py:550(_validate_names)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 readers.py:1779(__enter__)
#         1    0.000    0.000    0.000    0.000 parse.py:108(_noop)
#         1    0.000    0.000    0.000    0.000 multiarray.py:668(result_type)
#         1    0.000    0.000    0.000    0.000 copy.py:107(_copy_immutable)
#         2    0.000    0.000    0.000    0.000 shape_base.py:77(_atleast_2d_dispatcher)
#         1    0.000    0.000    0.000    0.000 series.py:577(_constructor)
#         1    0.000    0.000    0.000    0.000 series.py:4784(_needs_reindex_multi)

# %% [markdown]
# Example of the entire procedure.

# %%
example = binning.expand_df(test)
xmin = -76000 ; xmax = -67000
ymin = 69000 ; ymax = 78000

example = example[(example.loc[:,"X"]<xmax) & (example.loc[:,"X"]>xmin) 
                  & (example.loc[:,"Y"]<ymax) & (example.loc[:,"Y"]>ymin)]

fig,ax = plt.subplots(ncols=3,figsize=(18,6),sharey=True)

ax[0].scatter(example.loc[:,"X"].values,example.loc[:,"Y"].values,
           #c=(example.loc[:,"X"].values-xmin)+(example.loc[:,"Y"].values-ymin)*(xmax-xmin),
           s=0.5,
           c='indigo')
ax[0].set_aspect("equal")
ax[0].set_xlim([xmin,xmax])
ax[0].set_ylim([ymin,ymax])

ax[0].set_xlabel("x")
ax[0].set_ylabel("y")

ax[0].set_xticklabels([])

ax[0].annotate("Variables:\n"+example.iloc[7000].loc["Photodiode":"Spot area (um2)"].to_string()+"\n...",
               example.iloc[7000].loc["X":"Y"].to_numpy(),
               example.iloc[7000].loc["X":"Y"].to_numpy()+np.array([-1000,1000]),
               arrowprops={"width":0.3,'facecolor':'k'},
               bbox={'facecolor':'w', 'edgecolor':'black', 'boxstyle':'round,pad=0.5'})

# 2nd plot shows the bins
# Also use the test file to work out a rough bin 'mesh' for the build bed plane bins. 
x_grid,y_grid = binning.optimal_grid(["X","Y"],
                                          example,
                                          [1,1],
                                          sub_divisions=9,
                                          aux_variable="P",
                                          tol=100.0)
# Separate out the hatch from perimeter scans. 
example_hatchonly = []
starts,ends = binning.conditional_breakpoints(example)
for start,end in zip(starts,ends):
    if end - start <= 1:
        continue
    x,y = example.loc[start:end,("X","Y")].values.T
    # Determine whether this segment corresponds to hatching or some other part of the build layer. 
    score = binning.fft_recon_score(x,y)
    if score > 0.9:
        continue
    # Assuming the section is valid
    example_hatchonly.append(example.loc[start:end,:])
example_hatchonly = pd.concat(example_hatchonly)

vrange = plotting.calc_colour_range(example_hatchonly.loc[:,"Photodiode"].values)

ax[1].scatter(example_hatchonly.loc[:,"X"].values,example_hatchonly.loc[:,"Y"].values,
           s=0.5,
           c=example_hatchonly.loc[:,"Photodiode"].values,
           cmap="afmhot",
           vmin=vrange[0],vmax=vrange[1])
ax[1].set_aspect("equal")
ax[1].set_xlim([xmin,xmax])
ax[1].set_ylim([ymin,ymax])

ax[1].set_xlabel("x")
ax[1].set_ylabel("y")

ax[1].set_xticklabels([])

ax[1].hlines(y_grid,xmin,xmax,colors='grey')
ax[1].vlines(x_grid,ymin,ymax,colors='grey')

# 3rd plot shows the bin data.
example_bins = binning.DataBins(["X","Y"],[x_grid,y_grid],
                                     var_labels)
binning.process_dataframe(example,example_bins)
vrange_bins = plotting.plot_planar_bins(ax[2],example_bins,"Photodiode","mean",vrange=vrange,normalisation='linear',cmap="afmhot")

ax[2].hlines(y_grid,xmin,xmax,colors='grey')
ax[2].vlines(x_grid,ymin,ymax,colors='grey')

ax[2].set_aspect("equal")
ax[2].set_xlim([xmin,xmax])
ax[2].set_ylim([ymin,ymax])

ax[2].set_xlabel("x")
ax[2].set_ylabel("y")

ax[2].set_xticklabels([])
ax[2].set_yticklabels([])
# Out:
# []
